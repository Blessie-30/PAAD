# %%
install.packages("cmapR")
library(cmapR)

# %%
data=read.gct("C:/Users/Blessie/Documents/PAAD.gct")
head(data)

# %%
df = subset(data, select = -("neuroendocrine"))

# %%
![caption for the picture.]("c:/users/downloads/"newplot.png")

# %%
# By visualizing the gct files using phantasus, it can be seen that the data contains the gene expression profiles of all the gene which play a major role in pancreatic adenocarcinoma
# By performing PCA analysis we can see that it contains two broad categories of pancreatic adenocarcinoma the exocrine and neuroendocrine.
